# %%
# x générés avec 4 colonnes + y 1 colonne

# %%
import numpy as np
np.random.seed(40)
data = np.random.randn(1000,5)
data
# Out:
# array([[-0.6075477 , -0.12613641, -0.68460636,  0.92871475, -1.84440103],
#        [-0.46700242,  2.29249034,  0.48881005,  0.71026699,  1.05553444],
#        [ 0.0540731 ,  0.25795342,  0.58828165,  0.88524424, -1.01700702],
#        ...,
#        [-2.07845099,  1.05357819, -0.00338015, -0.26493264, -0.32745405],
#        [ 0.08900022, -1.36364527, -1.6288392 ,  0.40053058, -1.33190619],
#        [-0.49959398, -1.37677966,  0.50619891,  0.47510387, -0.15084442]])

# %% [markdown]
# 1.Construire un fichier csv multilinear.csv à l'aide de votre data et pandas

# %%
import pandas as pd
df = pd.DataFrame(data)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
df.to_csv('/content/gdrive/MyDrive/Module_IA_UM6P_LAHOUSSINE_BOUZZIT/LAB_01/Fwd_ Datasets + Notebook N°1 Régression Linéaire/my_data.csv')

# %%
df.describe()
# Out:
#                  0            1            2            3            4
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      0.037556     0.028025    -0.034407     0.031791    -0.013969
# std       0.990317     0.976972     1.006270     1.019718     0.974396
# min      -2.969436    -3.017768    -3.539488    -3.920425    -3.067279
# 25%      -0.593885    -0.619259    -0.689261    -0.651797    -0.694912
# 50%       0.032089     0.050121    -0.040667     0.064340    -0.015611
# 75%       0.702345     0.683289     0.603427     0.789746     0.642829
# max       3.437449     3.300772     3.305524     3.191612     3.243216

# %%
ind = ['F1', 'F2', 'F3', 'F4','Outcome']
df.set_axis(ind, axis=1, inplace=True)
# Out:
# <ipython-input-20-8e7a8e65cfc4>:2: FutureWarning: DataFrame.set_axis 'inplace' keyword is deprecated and will be removed in a future version. Use `obj = obj.set_axis(..., copy=False)` instead
#   df.set_axis(ind, axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Feature1  1000 non-null   float64
#  1   Feature2  1000 non-null   float64
#  2   Feature3  1000 non-null   float64
#  3   Feature4  1000 non-null   float64
#  4   Outcome   1000 non-null   float64
# dtypes: float64(5)
# memory usage: 39.2 KB

# %%
x=df[['F1','F2','F3','F4']]
y=df['Outcome']

# %%
df.columns
# Out:
# Index(['F1', 'F2', 'F3', 'F4', 'Outcome'], dtype='object')

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3, random_state=0)
lr= LinearRegression()
lr.fit(x_train,y_train)
print("coef:", lr.coef_)
print("intercept:", lr.intercept_ )
# Out:
# coef: [ 0.08617613  0.00401811 -0.01851517  0.0408207 ]
# intercept: -0.02896105222715689

# %%
predict=lr.predict(x_test)
print('MSE : ',metrics.mean_squared_error(y_test,predict))
print('RMSE : ',np.sqrt(metrics.mean_squared_error(y_test,predict)))
# Out:
# MSE :  0.9038574859170914
# RMSE :  0.9507141978097788
