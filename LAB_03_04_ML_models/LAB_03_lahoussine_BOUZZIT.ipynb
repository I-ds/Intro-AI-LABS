# %% [markdown]
# PREMIER CODE "UNE SIMPLE COUCHE" AVEC TENSORFLOW KERAS

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras
import matplotlib.pyplot as plt

# %% [markdown]
# on construit un modèle en une seule couche dense simple 'layer_0'

# %%
layer_0 = keras.layers.Dense(units =1 , input_shape = [1])
model = tf.keras.Sequential([layer_0])
opt = tf.keras.optimizers.SGD()
model.compile(optimizer=opt, loss='mean_squared_error')

print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 1)                 2
#
# ...
# Total params: 2 (8.00 Byte)
# Trainable params: 2 (8.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
xs=np.array([-1.0,0.0,1.0,2.0,3.0,4.0])
ys=np.array([-3.0, -1.0,1.0,2.0,3.0,4.0])

#entrainement du modèle
model.fit(xs,ys,epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 448ms/step - loss: 22.1877
# Epoch 2/500
# 1/1 [==============================] - 0s 8ms/step - loss: 17.7907
# Epoch 3/500
# 1/1 [==============================] - 0s 8ms/step - loss: 14.3252
# Epoch 4/500
# 1/1 [==============================] - 0s 13ms/step - loss: 11.5929
# Epoch 5/500
# 1/1 [==============================] - 0s 10ms/step - loss: 9.4373
# Epoch 6/500
# 1/1 [==============================] - 0s 9ms/step - loss: 7.7357
# Epoch 7/500
# 1/1 [==============================] - 0s 7ms/step - loss: 6.3914
# Epoch 8/500
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3283
# Epoch 9/500
# 1/1 [==============================] - 0s 10ms/step - loss: 4.4865
# Epoch 10/500
# 1/1 [==============================] - 0s 9ms/step - loss: 3.8190
# Epoch 11/500
# 1/1 [==============================] - 0s 8ms/step - loss: 3.2887
# Epoch 12/500
# 1/1 [==============================] - 0s 8ms/step - loss: 2.8664
# ...

# %%
plt.scatter (xs,ys)

# %% [markdown]
# on teste le modèle en réalisant une prédiction sur une nouvelle valeur
