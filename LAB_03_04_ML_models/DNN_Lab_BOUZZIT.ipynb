# %% [markdown]
# # Regression Problem

# %% [markdown]
# ## Data importation and processing

# %%
#On monte le drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# On importe les librairies dont on aura besoin
# %matplotlib inline


import numpy as np
import pandas as pd
import matplotlib
from matplotlib import pyplot as plt

# On charge le dataset
data_industriel = pd.read_csv('/content/gdrive/MyDrive/Module_IA_UM6P_LAHOUSSINE_BOUZZIT/LAB_03/exemple_dataset_industriel.csv')

# %%
x_ind      = data_industriel.iloc[:, 0:4]
y_ind  = data_industriel.iloc[:, 4:6]

from sklearn.model_selection import train_test_split
x_ind_train, x_ind_test, y_ind_train,y_ind_test = train_test_split(x_ind,y_ind ,
                          random_state=28,
                          train_size=0.8)

# %% [markdown]
# ## Linear regression model

# %%
from sklearn.linear_model import LinearRegression

model_lr = LinearRegression(
    fit_intercept = True
    )
model_lr.fit(x_ind_train,y_ind_train)

y_pred_lr = model_lr.predict(x_ind_test)

from sklearn import metrics

mae = metrics.mean_absolute_error(y_ind_test, y_pred_lr)
mse = metrics.mean_squared_error(y_ind_test, y_pred_lr)
r2 = metrics.r2_score(y_ind_test, y_pred_lr)


print('MAE : {}'.format(mae))
print('MSE : {}'.format(mse))
print('R2 score : {}'.format(r2))
# Out:
# MAE : 3.5485309148582678
# MSE : 17.875336040388355
# R2 score : 0.46033607968898915

# %% [markdown]
# ## Decision tree regression

# %%
x_ind_train, x_ind_test, y_ind_train,y_ind_test
# Out:
# (    Feature_1  Feature_2  Feature_3  Feature_4
#  42   0.729991   0.171630   0.521037   0.054338
#  79   0.420539   0.557369   0.860551   0.727044
#  50   0.311796   0.696343   0.377752   0.179604
#  46   0.934214   0.613966   0.535633   0.589910
#  62   0.144848   0.488056   0.355613   0.940432
#  ..        ...        ...        ...        ...
#  3    0.568045   0.925597   0.071036   0.087129
#  32   0.660174   0.290078   0.618015   0.428769
#  22   0.575946   0.929296   0.318569   0.667410
#  5    0.978618   0.799159   0.461479   0.780529
#  1    0.423655   0.645894   0.437587   0.891773
#
#  [80 rows x 4 columns],
#      Feature_1  Feature_2  Feature_3  Feature_4
#  67   0.063955   0.485628   0.977495   0.876505
#  14   0.653108   0.253292   0.466311   0.244426
#  0    0.548814   0.715189   0.602763   0.544883
#  86   0.799796   0.076956   0.518835   0.306810
#  13   0.988374   0.102045   0.208877   0.161310
#  18   0.976761   0.604846   0.739264   0.039188
# ...

# %%
from sklearn.tree import DecisionTreeRegressor

model_dt = DecisionTreeRegressor(max_depth=3)
model_dt.fit(x_ind_train, y_ind_train)

# Effectuez des prédictions sur l'ensemble de test
y_pred = model_dt.predict(x_ind_test)

from sklearn import metrics

mae = metrics.mean_absolute_error(y_ind_test, y_pred)
mse = metrics.mean_squared_error(y_ind_test, y_pred)
r2 = metrics.r2_score(y_ind_test, y_pred)


print('MAE : {}'.format(mae))
print('MSE : {}'.format(mse))
print('R2 score : {}'.format(r2))
# Out:
# MAE : 4.5005732001720435
# MSE : 30.94581166355815
# R2 score : 0.06733618734237268

# %% [markdown]
# ## Random forest regression

# %%
from sklearn.ensemble import RandomForestRegressor

model_rf = RandomForestRegressor(max_depth=3, random_state=28,n_estimators=100)
model_rf.fit(x_ind_train, y_ind_train)

# Effectuez des prédictions sur l'ensemble de test
y_pred = model_rf.predict(x_ind_test)

from sklearn import metrics

mae = metrics.mean_absolute_error(y_ind_test, y_pred)
mse = metrics.mean_squared_error(y_ind_test, y_pred)
r2 = metrics.r2_score(y_ind_test, y_pred)


print('MAE : {}'.format(mae))
print('MSE : {}'.format(mse))
print('R2 score : {}'.format(r2))
# Out:
# MAE : 4.1302802080542715
# MSE : 24.41764825500725
# R2 score : 0.244212024194917

# %% [markdown]
# ## SVM

# %%
y_ind_train

# %%
from sklearn.svm import SVR
from sklearn.multioutput import MultiOutputRegressor

svr = SVR(epsilon=0.2)
model_svr = MultiOutputRegressor(svr)
model_svr.fit(x_ind_train, y_ind_train)

# Effectuez des prédictions sur l'ensemble de test
y_pred = model_svr.predict(x_ind_test)

from sklearn import metrics

mae = metrics.mean_absolute_error(y_ind_test, y_pred)
mse = metrics.mean_squared_error(y_ind_test, y_pred)
r2 = metrics.r2_score(y_ind_test, y_pred)


print('MAE : {}'.format(mae))
print('MSE : {}'.format(mse))
print('R2 score : {}'.format(r2))
# Out:
# MAE : 4.231292391106039
# MSE : 25.79113421076947
# R2 score : 0.22457985006840747

# %% [markdown]
# # Classification

# %% [markdown]
# ## Importing dataset

# %%
# %matplotlib inline


import numpy as np
import pandas as pd
import matplotlib
from matplotlib import pyplot as plt

# On charge le dataset
data_industriel = pd.read_csv('/content/gdrive/MyDrive/Module_IA_UM6P_LAHOUSSINE_BOUZZIT/LAB_03/data_industriel_classif.csv')

# %%
x_ind      = data_industriel.iloc[:, 0:4]
y_ind  = data_industriel.iloc[:, 4:5]

from sklearn.model_selection import train_test_split
x_ind_train, x_ind_test, y_ind_train,y_ind_test = train_test_split(x_ind,y_ind ,
                          random_state=104,
                          train_size=0.8)

# %% [markdown]
# ## DNN classification

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# Créer un modèle avec plusieurs couches et neurones pour la classification
model = tf.keras.Sequential([
    # tf.keras.layers.Dense(units=128, input_dim=4, activation='linear'),
    # tf.keras.layers.Dense(units=128, activation='relu'),
    tf.keras.layers.Flatten(input_shape=(4, 1)),
    tf.keras.layers.Dense(units=256, activation='relu'),
    tf.keras.layers.Dense(units=128, activation='relu'),
    tf.keras.layers.Dense(units=64, activation='relu'),
    tf.keras.layers.Dense(units=32, activation='relu'),
    tf.keras.layers.Dense(units=16, activation='relu'),
    tf.keras.layers.Dense(units=8, activation='relu'),
    tf.keras.layers.Dense(units=1, activation='sigmoid')
])

# Compiler le modèle
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Entraîner le modèle
model.fit(x_ind_train, y_ind_train, epochs=500, verbose=0)

# Prédire les classes
y_pred = (model.predict(x_ind_test) > 0.5).astype(int)

# Évaluer les performances du modèle
accuracy = (np.array(y_ind_test) == y_pred.squeeze()).mean()
print(f'Accuracy: {accuracy:.2f}')
# Out:
# 7/7 [==============================] - 0s 2ms/step
# Accuracy: 0.89

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# Créer un modèle avec plusieurs couches et neurones pour la classification


model = tf.keras.Sequential([
    tf.keras.layers.Dense(units=16, input_dim=4, activation='linear'),
    tf.keras.layers.Dense(units=12, activation='relu'),
    tf.keras.layers.Dense(units=8, activation='relu'),
    tf.keras.layers.Dense(units=4, activation='relu'),
    tf.keras.layers.Dense(units=2, activation='linear'),
    tf.keras.layers.Dense(units=1, activation='sigmoid')
])

# Compiler le modèle
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Entraîner le modèle
model.fit(x_ind_train, y_ind_train, epochs=1000, verbose=0)

# Prédire les classes
y_pred = (model.predict(x_ind_test) > 0.5).astype(int)

# Évaluer les performances du modèle
accuracy = (np.array(y_ind_test) == y_pred.squeeze()).mean()
print(f'Accuracy: {accuracy:.2f}')
# Out:
# 7/7 [==============================] - 0s 2ms/step
# Accuracy: 0.88

# %%
import numpy as np
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score



# Diviser les données en ensembles d'apprentissage et de test
X_train, X_test, y_train, y_test = train_test_split(x_ind, y_ind, test_size=0.3, random_state=42)

# Prétraitement des données (normalisation)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Créer et entraîner les modèles de classification
models = {
    "Random Forest": RandomForestClassifier(n_estimators=4, random_state=42),
    "Support Vector Machine": SVC(kernel='linear', C=1),
    "K-Nearest Neighbors": KNeighborsClassifier(n_neighbors=3),
    "Decision Tree": DecisionTreeClassifier(max_depth = 4, random_state=42)
}

results = {}

for model_name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    results[model_name] = accuracy

# Comparer les performances des modèles
for model_name, accuracy in results.items():
    print(f"{model_name}: Accuracy = {accuracy:.2f}")
# Out:
# Random Forest: Accuracy = 0.99
# Support Vector Machine: Accuracy = 0.90
# K-Nearest Neighbors: Accuracy = 0.95
# Decision Tree: Accuracy = 0.97
# <ipython-input-14-3c00e8f50075>:32: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(X_train, y_train)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
